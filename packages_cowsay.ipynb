# %%
import cowsay

# %%
#get a list of possible character 
#format is module.function
cowsay.char_names
# Out:
# ['beavis',
#  'cheese',
#  'cow',
#  'daemon',
#  'dragon',
#  'fox',
#  'ghostbusters',
#  'kitty',
#  'meow',
#  'miki',
#  'milk',
#  'octopus',
#  'pig',
#  'stegosaurus',
#  'stimpy',
#  'trex',
#  'turkey',
#  'turtle',
#  'tux']

# %%
#cowsay.beavis('hello, world')
cowsay.turtle('hello, world')
# Out:
#   ____________
# | hello, world |
# ...
#               \
#                \
#                 \
#                  \
#                                             ___-------___
#                                         _-~~             ~~-_
#                                      _-~                    /~-_
#                    /^\__/^\         /~  \                   /    \
#                  /|  O|| O|        /      \_______________/        \
#                 | |___||__|      /       /                \          \
#                 |          \    /      /                    \          \
#                 |   (_______) /______/                        \_________ \
#                 |         / /         \                      /            \
#                  \         \^\\         \                  /               \     /
#                    \         ||           \______________/      _-_       //\__//
#                      \       ||------_-~~-_ ------------- \ --/~   ~\    || __/
# ...
